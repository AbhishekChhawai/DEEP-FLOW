# %%
import os
import pandas as pd

file_path ="Train.csv"
if os.path.exists(file_path):
    chunk_iter = pd.read_csv(file_path, chunksize=1000)
    train = next(chunk_iter)
    print(train.head())
    print(train.info())
    print(train.describe())
    print(train.shape)
else:
    print(f"File not found: {file_path}. Please upload the file.")
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246      66000     999089     3157         121             3      2004
# 1  1139248      57000     117657       77         121             3      1996
# 2  1139249      10000     434808     7009         121             3      2001
# 3  1139251      38500    1026470      332         121             3      2001
# 4  1139253      11000    1057373    17311         121             3      2007
#
#    MachineHoursCurrentMeter UsageBand         saledate  ...  \
# 0                        68       Low  11/16/2006 0:00  ...
# 1                      4640       Low   3/26/2004 0:00  ...
# 2                      2838      High   2/26/2004 0:00  ...
# 3                      3486      High   5/19/2011 0:00  ...
# 4                       722    Medium   7/23/2009 0:00  ...
#
#   Undercarriage_Pad_Width Stick_Length Thumb Pattern_Changer Grouser_Type  \
# 0                     NaN          NaN   NaN             NaN          NaN
# 1                     NaN          NaN   NaN             NaN          NaN
# 2                     NaN          NaN   NaN             NaN          NaN
# 3                     NaN          NaN   NaN             NaN          NaN
# 4                     NaN          NaN   NaN             NaN          NaN
#
#   Backhoe_Mounting Blade_Type Travel_Controls Differential_Type  \
# 0              NaN        NaN             NaN          Standard
# 1              NaN        NaN             NaN          Standard
# 2              NaN        NaN             NaN               NaN
# 3              NaN        NaN             NaN               NaN
# 4              NaN        NaN             NaN               NaN
#
#   Steering_Controls
# 0      Conventional
# 1      Conventional
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 53 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SalesID                   1000 non-null   int64
#  1   SalePrice                 1000 non-null   int64
#  2   MachineID                 1000 non-null   int64
#  3   ModelID                   1000 non-null   int64
#  4   datasource                1000 non-null   int64
#  5   auctioneerID              1000 non-null   int64
#  6   YearMade                  1000 non-null   int64
#  7   MachineHoursCurrentMeter  1000 non-null   int64
#  8   UsageBand                 869 non-null    object
#  9   saledate                  1000 non-null   object
#  10  fiModelDesc               1000 non-null   object
#  11  fiBaseModel               1000 non-null   object
#  12  fiSecondaryDesc           651 non-null    object
#  13  fiModelSeries             137 non-null    object
#  14  fiModelDescriptor         235 non-null    object
#  15  ProductSize               463 non-null    object
#  16  fiProductClassDesc        1000 non-null   object
#  17  state                     1000 non-null   object
#  18  ProductGroup              1000 non-null   object
#  19  ProductGroupDesc          1000 non-null   object
#  20  Drive_System              219 non-null    object
#  21  Enclosure                 999 non-null    object
#  22  Forks                     505 non-null    object
#  23  Pad_Type                  160 non-null    object
#  24  Ride_Control              332 non-null    object
#  25  Stick                     160 non-null    object
#  26  Transmission              392 non-null    object
#  27  Turbocharged              160 non-null    object
#  28  Blade_Extension           59 non-null     object
#  29  Blade_Width               59 non-null     object
#  30  Enclosure_Type            59 non-null     object
#  31  Engine_Horsepower         59 non-null     object
#  32  Hydraulics                838 non-null    object
#  33  Pushblock                 59 non-null     object
#  34  Ripper                    231 non-null    object
#  35  Scarifier                 59 non-null     object
#  36  Tip_Control               59 non-null     object
#  37  Tire_Size                 231 non-null    object
#  38  Coupler                   601 non-null    object
#  39  Coupler_System            174 non-null    object
#  40  Grouser_Tracks            173 non-null    object
#  41  Hydraulics_Flow           173 non-null    object
#  42  Track_Type                253 non-null    object
#  43  Undercarriage_Pad_Width   256 non-null    object
#  44  Stick_Length              253 non-null    object
#  45  Thumb                     253 non-null    object
#  46  Pattern_Changer           253 non-null    object
#  47  Grouser_Type              253 non-null    object
#  48  Backhoe_Mounting          171 non-null    object
#  49  Blade_Type                173 non-null    object
#  50  Travel_Controls           172 non-null    object
#  51  Differential_Type         172 non-null    object
#  52  Steering_Controls         172 non-null    object
# dtypes: int64(8), object(45)
# memory usage: 414.2+ KB
# None
#             SalesID      SalePrice     MachineID      ModelID  datasource  \
# count  1.000000e+03    1000.000000  1.000000e+03   1000.00000      1000.0
# mean   1.140894e+06   33199.900000  8.550340e+05   7951.04500       121.0
# std    9.585394e+02   24318.819975  3.091412e+05   7310.69434         0.0
# min    1.139246e+06    4750.000000  4.527000e+03     43.00000       121.0
# 25%    1.140068e+06   14500.000000  7.526065e+05   3356.75000       121.0
# 50%    1.140914e+06   26500.000000  1.016916e+06   4754.00000       121.0
# 75%    1.141686e+06   44000.000000  1.046307e+06  10569.00000       121.0
# max    1.142582e+06  141000.000000  1.069733e+06  36540.00000       121.0
#
#        auctioneerID     YearMade  MachineHoursCurrentMeter
# count        1000.0  1000.000000               1000.000000
# mean            3.0  1866.880000               4191.142000
# std             0.0   339.743929               5177.540358
# min             3.0  1000.000000                  0.000000
# 25%             3.0  1995.000000                781.250000
# 50%             3.0  2000.000000               2374.000000
# 75%             3.0  2004.000000               5860.250000
# max             3.0  2008.000000              37796.000000
# (1000, 53)

# %%
train.isnull().sum()
# Out:
# SalesID                       0
# SalePrice                     0
# MachineID                     0
# ModelID                       0
# datasource                    0
# auctioneerID                  0
# YearMade                      0
# MachineHoursCurrentMeter      0
# UsageBand                   131
# saledate                      0
# fiModelDesc                   0
# fiBaseModel                   0
# fiSecondaryDesc             349
# fiModelSeries               863
# fiModelDescriptor           765
# ProductSize                 537
# fiProductClassDesc            0
# state                         0
# ProductGroup                  0
# ProductGroupDesc              0
# Drive_System                781
# Enclosure                     1
# Forks                       495
# Pad_Type                    840
# Ride_Control                668
# Stick                       840
# Transmission                608
# Turbocharged                840
# Blade_Extension             941
# Blade_Width                 941
# Enclosure_Type              941
# Engine_Horsepower           941
# Hydraulics                  162
# Pushblock                   941
# Ripper                      769
# Scarifier                   941
# Tip_Control                 941
# Tire_Size                   769
# Coupler                     399
# Coupler_System              826
# Grouser_Tracks              827
# Hydraulics_Flow             827
# Track_Type                  747
# Undercarriage_Pad_Width     744
# Stick_Length                747
# Thumb                       747
# Pattern_Changer             747
# Grouser_Type                747
# Backhoe_Mounting            829
# Blade_Type                  827
# Travel_Controls             828
# Differential_Type           828
# Steering_Controls           828
# dtype: int64

# %%
print(train.isnull().sum())

print(train.dtypes)

import matplotlib.pyplot as plt
plt.hist(train['SalePrice'], bins=50)
plt.xlabel('SalePrice')
plt.ylabel('Frequency')
plt.show()
# Out:
# SalesID                       0
# SalePrice                     0
# MachineID                     0
# ModelID                       0
# datasource                    0
# auctioneerID                  0
# YearMade                      0
# MachineHoursCurrentMeter      0
# UsageBand                   131
# saledate                      0
# fiModelDesc                   0
# fiBaseModel                   0
# fiSecondaryDesc             349
# fiModelSeries               863
# fiModelDescriptor           765
# ProductSize                 537
# fiProductClassDesc            0
# state                         0
# ProductGroup                  0
# ProductGroupDesc              0
# Drive_System                781
# Enclosure                     1
# Forks                       495
# Pad_Type                    840
# Ride_Control                668
# Stick                       840
# Transmission                608
# Turbocharged                840
# Blade_Extension             941
# Blade_Width                 941
# Enclosure_Type              941
# Engine_Horsepower           941
# Hydraulics                  162
# Pushblock                   941
# Ripper                      769
# Scarifier                   941
# Tip_Control                 941
# Tire_Size                   769
# Coupler                     399
# Coupler_System              826
# Grouser_Tracks              827
# Hydraulics_Flow             827
# Track_Type                  747
# Undercarriage_Pad_Width     744
# Stick_Length                747
# Thumb                       747
# Pattern_Changer             747
# Grouser_Type                747
# Backhoe_Mounting            829
# Blade_Type                  827
# Travel_Controls             828
# Differential_Type           828
# Steering_Controls           828
# dtype: int64
# SalesID                      int64
# SalePrice                    int64
# MachineID                    int64
# ModelID                      int64
# datasource                   int64
# auctioneerID                 int64
# YearMade                     int64
# MachineHoursCurrentMeter     int64
# UsageBand                   object
# saledate                    object
# fiModelDesc                 object
# fiBaseModel                 object
# fiSecondaryDesc             object
# fiModelSeries               object
# fiModelDescriptor           object
# ProductSize                 object
# fiProductClassDesc          object
# state                       object
# ProductGroup                object
# ProductGroupDesc            object
# Drive_System                object
# Enclosure                   object
# Forks                       object
# Pad_Type                    object
# Ride_Control                object
# Stick                       object
# Transmission                object
# Turbocharged                object
# Blade_Extension             object
# Blade_Width                 object
# Enclosure_Type              object
# Engine_Horsepower           object
# Hydraulics                  object
# Pushblock                   object
# Ripper                      object
# Scarifier                   object
# Tip_Control                 object
# Tire_Size                   object
# Coupler                     object
# Coupler_System              object
# Grouser_Tracks              object
# Hydraulics_Flow             object
# Track_Type                  object
# Undercarriage_Pad_Width     object
# Stick_Length                object
# Thumb                       object
# Pattern_Changer             object
# Grouser_Type                object
# Backhoe_Mounting            object
# Blade_Type                  object
# Travel_Controls             object
# Differential_Type           object
# Steering_Controls           object
# dtype: object

# %%
print(train.isnull().sum())

print(train.dtypes)

import matplotlib.pyplot as plt
plt.hist(train['SalePrice'], bins=50)
plt.xlabel('SalePrice')
plt.ylabel('Frequency')
plt.show()
# Out:
# SalesID                       0
# SalePrice                     0
# MachineID                     0
# ModelID                       0
# datasource                    0
# auctioneerID                  0
# YearMade                      0
# MachineHoursCurrentMeter      0
# UsageBand                   131
# saledate                      0
# fiModelDesc                   0
# fiBaseModel                   0
# fiSecondaryDesc             349
# fiModelSeries               863
# fiModelDescriptor           765
# ProductSize                 537
# fiProductClassDesc            0
# state                         0
# ProductGroup                  0
# ProductGroupDesc              0
# Drive_System                781
# Enclosure                     1
# Forks                       495
# Pad_Type                    840
# Ride_Control                668
# Stick                       840
# Transmission                608
# Turbocharged                840
# Blade_Extension             941
# Blade_Width                 941
# Enclosure_Type              941
# Engine_Horsepower           941
# Hydraulics                  162
# Pushblock                   941
# Ripper                      769
# Scarifier                   941
# Tip_Control                 941
# Tire_Size                   769
# Coupler                     399
# Coupler_System              826
# Grouser_Tracks              827
# Hydraulics_Flow             827
# Track_Type                  747
# Undercarriage_Pad_Width     744
# Stick_Length                747
# Thumb                       747
# Pattern_Changer             747
# Grouser_Type                747
# Backhoe_Mounting            829
# Blade_Type                  827
# Travel_Controls             828
# Differential_Type           828
# Steering_Controls           828
# dtype: int64
# SalesID                      int64
# SalePrice                    int64
# MachineID                    int64
# ModelID                      int64
# datasource                   int64
# auctioneerID                 int64
# YearMade                     int64
# MachineHoursCurrentMeter     int64
# UsageBand                   object
# saledate                    object
# fiModelDesc                 object
# fiBaseModel                 object
# fiSecondaryDesc             object
# fiModelSeries               object
# fiModelDescriptor           object
# ProductSize                 object
# fiProductClassDesc          object
# state                       object
# ProductGroup                object
# ProductGroupDesc            object
# Drive_System                object
# Enclosure                   object
# Forks                       object
# Pad_Type                    object
# Ride_Control                object
# Stick                       object
# Transmission                object
# Turbocharged                object
# Blade_Extension             object
# Blade_Width                 object
# Enclosure_Type              object
# Engine_Horsepower           object
# Hydraulics                  object
# Pushblock                   object
# Ripper                      object
# Scarifier                   object
# Tip_Control                 object
# Tire_Size                   object
# Coupler                     object
# Coupler_System              object
# Grouser_Tracks              object
# Hydraulics_Flow             object
# Track_Type                  object
# Undercarriage_Pad_Width     object
# Stick_Length                object
# Thumb                       object
# Pattern_Changer             object
# Grouser_Type                object
# Backhoe_Mounting            object
# Blade_Type                  object
# Travel_Controls             object
# Differential_Type           object
# Steering_Controls           object
# dtype: object

# %%
train.isnull().sum()
# Out:
# SalesID                       0
# SalePrice                     0
# MachineID                     0
# ModelID                       0
# datasource                    0
# auctioneerID                  0
# YearMade                      0
# MachineHoursCurrentMeter      0
# UsageBand                   131
# saledate                      0
# fiModelDesc                   0
# fiBaseModel                   0
# fiSecondaryDesc             349
# fiModelSeries               863
# fiModelDescriptor           765
# ProductSize                 537
# fiProductClassDesc            0
# state                         0
# ProductGroup                  0
# ProductGroupDesc              0
# Drive_System                781
# Enclosure                     1
# Forks                       495
# Pad_Type                    840
# Ride_Control                668
# Stick                       840
# Transmission                608
# Turbocharged                840
# Blade_Extension             941
# Blade_Width                 941
# Enclosure_Type              941
# Engine_Horsepower           941
# Hydraulics                  162
# Pushblock                   941
# Ripper                      769
# Scarifier                   941
# Tip_Control                 941
# Tire_Size                   769
# Coupler                     399
# Coupler_System              826
# Grouser_Tracks              827
# Hydraulics_Flow             827
# Track_Type                  747
# Undercarriage_Pad_Width     744
# Stick_Length                747
# Thumb                       747
# Pattern_Changer             747
# Grouser_Type                747
# Backhoe_Mounting            829
# Blade_Type                  827
# Travel_Controls             828
# Differential_Type           828
# Steering_Controls           828
# dtype: int64

# %%
# Convert columns if needed, e.g., dates
train['saledate'] = pd.to_datetime(train['saledate'])
train['year']=train['saledate'].dt.year
train['month']=train['saledate'].dt.month
train['day']=train['saledate'].dt.day

# Drop columns that are not useful (e.g., identifiers except SalesID)
#train = train.drop(['SalesID', 'MachineID'], axis=1)

# %%
train=train.drop(['saledate','SalesID','MachineID'], axis=1, errors='ignore')

# %%
train = pd.get_dummies(train)

# %%
# handling missing value
# Fill numeric columns with median
train = train.fillna(train.median(numeric_only=True))

# Fill categorical columns with mode
for col in train.select_dtypes(include='object').columns:
    train[col] = train[col].fillna(train[col].mode()[0])
train.isnull().sum()   # checking for missing value
# Out:
# SalePrice                            0
# ModelID                              0
# datasource                           0
# auctioneerID                         0
# YearMade                             0
#                                     ..
# Travel_Controls_Pedal                0
# Differential_Type_Limited Slip       0
# Differential_Type_Standard           0
# Steering_Controls_Command Control    0
# Steering_Controls_Conventional       0
# Length: 1218, dtype: int64

# %%
import pandas as pd

# Load datasets
test = pd.read_csv('Test.csv')

# handling missing value
# Fill numeric columns with median
test = test.fillna(test.median(numeric_only=True))

# Fill categorical columns with mode
for col in test.select_dtypes(include='object').columns:
    test[col] = test[col].fillna(test[col].mode()[0])
test.isnull().sum()   # checking for missing value


valid = pd.read_csv('Valid.csv')


# handling missing value
# Fill numeric columns with median
valid = valid.fillna(valid.median(numeric_only=True))

# Fill categorical columns with mode
for col in valid.select_dtypes(include='object').columns:
    valid[col] = valid[col].fillna(valid[col].mode()[0])
valid.isnull().sum()   # checking for missing value
# List of datasets for batch processing
datasets = [test, valid]


for df in datasets:
    # Fill missing numeric values with median
    for col in df.select_dtypes(include=['float64', 'int64']):
        df[col].fillna(df[col].median(), inplace=True)
    # Fill missing categorical values with mode
    for col in df.select_dtypes(include=['object']):
        df[col].fillna(df[col].mode()[0], inplace=True)
    # Convert 'saledate' to datetime and extract year and month
    df['saledate'] = pd.to_datetime(df['saledate'])
    df['year'] = df['saledate'].dt.year
    df['month'] = df['saledate'].dt.month
    # Drop non-useful columns
    
    df.drop([ 'MachineID', 'ModelID', 'datasource', 'auctioneerID'], axis=1, inplace=True, errors='ignore')
    # One-hot encode categorical variables
    df = pd.get_dummies(df)
    # Assign back to variable (important if you want to use the processed version)
    if df is test:
        test = df
    else:
        valid = df

# Show info to verify
print(test.head())
print(test.info())
print(valid.head())
print(valid.info())
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_8072\3059673568.py:34: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\abhis\AppData\Local\Temp\ipykernel_8072\3059673568.py:34: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\abhis\AppData\Local\Temp\ipykernel_8072\3059673568.py:34: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\abhis\AppData\Local\Temp\ipykernel_8072\3059673568.py:34: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\abhis\AppData\Local\Temp\ipykernel_8072\3059673568.py:34: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\abhis\AppData\Local\Temp\ipykernel_8072\3059673568.py:34: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\abhis\AppData\Local\Temp\ipykernel_8072\3059673568.py:34: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\abhis\AppData\Local\Temp\ipykernel_8072\3059673568.py:37: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)
# C:\Users\abhis\AppData\Local\Temp\ipykernel_8072\3059673568.py:34: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\abhis\AppData\Local\Temp\ipykernel_8072\3059673568.py:34: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\abhis\AppData\Local\Temp\ipykernel_8072\3059673568.py:34: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\abhis\AppData\Local\Temp\ipykernel_8072\3059673568.py:34: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\abhis\AppData\Local\Temp\ipykernel_8072\3059673568.py:34: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\abhis\AppData\Local\Temp\ipykernel_8072\3059673568.py:34: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\abhis\AppData\Local\Temp\ipykernel_8072\3059673568.py:34: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\abhis\AppData\Local\Temp\ipykernel_8072\3059673568.py:37: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)
#    SalesID  YearMade  MachineHoursCurrentMeter UsageBand   saledate  \
# 0  1227829      1999                    3688.0       Low 2012-05-03
# 1  1227844      1000                   28555.0      High 2012-05-10
# 2  1227847      2004                    6038.0    Medium 2012-05-10
# 3  1227848      2006                    8940.0      High 2012-05-10
# 4  1227863      2005                    2286.0       Low 2012-05-10
#
#   fiModelDesc fiBaseModel fiSecondaryDesc fiModelSeries fiModelDescriptor  \
# 0        580G         580               G            II                 L
# 1         936         936               G            II                 L
# 2    EC210BLC       EC210               B            II                LC
# 3       330CL         330               C            II                 L
# 4        650K         650               K            II                 L
#
#    ...                Thumb      Pattern_Changer Grouser_Type  \
# 0  ...  None or Unspecified  None or Unspecified       Double
# 1  ...  None or Unspecified  None or Unspecified       Double
# 2  ...               Manual  None or Unspecified       Double
# 3  ...               Manual                  Yes       Triple
# 4  ...  None or Unspecified  None or Unspecified       Double
#
#       Backhoe_Mounting Blade_Type      Travel_Controls Differential_Type  \
# 0  None or Unspecified        PAT  None or Unspecified          Standard
# 1  None or Unspecified        PAT  None or Unspecified          Standard
# 2  None or Unspecified        PAT  None or Unspecified          Standard
# 3  None or Unspecified        PAT  None or Unspecified          Standard
# 4  None or Unspecified        PAT  None or Unspecified          Standard
#
#   Steering_Controls  year month
# 0      Conventional  2012     5
# 1      Conventional  2012     5
# 2      Conventional  2012     5
# 3      Conventional  2012     5
# 4      Conventional  2012     5
#
# [5 rows x 50 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12457 entries, 0 to 12456
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SalesID                   12457 non-null  int64
#  1   YearMade                  12457 non-null  int64
#  2   MachineHoursCurrentMeter  12457 non-null  float64
#  3   UsageBand                 12457 non-null  object
#  4   saledate                  12457 non-null  datetime64[ns]
#  5   fiModelDesc               12457 non-null  object
#  6   fiBaseModel               12457 non-null  object
#  7   fiSecondaryDesc           12457 non-null  object
#  8   fiModelSeries             12457 non-null  object
#  9   fiModelDescriptor         12457 non-null  object
#  10  ProductSize               12457 non-null  object
#  11  fiProductClassDesc        12457 non-null  object
#  12  state                     12457 non-null  object
#  13  ProductGroup              12457 non-null  object
#  14  ProductGroupDesc          12457 non-null  object
#  15  Drive_System              12457 non-null  object
#  16  Enclosure                 12457 non-null  object
#  17  Forks                     12457 non-null  object
#  18  Pad_Type                  12457 non-null  object
#  19  Ride_Control              12457 non-null  object
#  20  Stick                     12457 non-null  object
#  21  Transmission              12457 non-null  object
#  22  Turbocharged              12457 non-null  object
#  23  Blade_Extension           12457 non-null  object
#  24  Blade_Width               12457 non-null  object
#  25  Enclosure_Type            12457 non-null  object
#  26  Engine_Horsepower         12457 non-null  object
#  27  Hydraulics                12457 non-null  object
#  28  Pushblock                 12457 non-null  object
#  29  Ripper                    12457 non-null  object
#  30  Scarifier                 12457 non-null  object
#  31  Tip_Control               12457 non-null  object
#  32  Tire_Size                 12457 non-null  object
#  33  Coupler                   12457 non-null  object
#  34  Coupler_System            12457 non-null  object
#  35  Grouser_Tracks            12457 non-null  object
#  36  Hydraulics_Flow           12457 non-null  object
#  37  Track_Type                12457 non-null  object
#  38  Undercarriage_Pad_Width   12457 non-null  object
#  39  Stick_Length              12457 non-null  object
#  40  Thumb                     12457 non-null  object
#  41  Pattern_Changer           12457 non-null  object
#  42  Grouser_Type              12457 non-null  object
#  43  Backhoe_Mounting          12457 non-null  object
#  44  Blade_Type                12457 non-null  object
#  45  Travel_Controls           12457 non-null  object
#  46  Differential_Type         12457 non-null  object
#  47  Steering_Controls         12457 non-null  object
#  48  year                      12457 non-null  int32
#  49  month                     12457 non-null  int32
# dtypes: datetime64[ns](1), float64(1), int32(2), int64(2), object(44)
# memory usage: 4.7+ MB
# None
#    SalesID  YearMade  MachineHoursCurrentMeter   saledate  year  month  \
# 0  1222837      1000                       0.0 2012-01-05  2012      1
# 1  1222839      2006                    4412.0 2012-01-05  2012      1
# 2  1222841      2000                   10127.0 2012-01-05  2012      1
# 3  1222843      1000                    4682.0 2012-01-05  2012      1
# 4  1222845      2002                    8150.0 2012-01-04  2012      1
#
#    UsageBand_High  UsageBand_Low  UsageBand_Medium  fiModelDesc_1080B  ...  \
# 0           False          False              True              False  ...
# 1           False          False              True              False  ...
# 2           False          False              True              False  ...
# 3           False           True             False              False  ...
# 4           False          False              True              False  ...
#
#    Travel_Controls_Finger Tip  Travel_Controls_Lever  \
# 0                       False                  False
# 1                       False                  False
# 2                       False                  False
# 3                       False                  False
# 4                       False                  False
#
#    Travel_Controls_None or Unspecified  Travel_Controls_Pedal  \
# 0                                 True                  False
# 1                                 True                  False
# 2                                 True                  False
# 3                                 True                  False
# 4                                 True                  False
#
#    Differential_Type_Limited Slip  Differential_Type_No Spin  \
# 0                           False                      False
# 1                           False                      False
# 2                           False                      False
# 3                           False                      False
# 4                           False                      False
#
#    Differential_Type_Standard  Steering_Controls_Command Control  \
# 0                        True                              False
# 1                        True                              False
# 2                        True                              False
# 3                        True                              False
# 4                        True                              False
#
#    Steering_Controls_Conventional  Steering_Controls_Four Wheel Standard
# 0                            True                                  False
# 1                            True                                  False
# 2                            True                                  False
# 3                            True                                  False
# 4                            True                                  False
#
# [5 rows x 3029 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11573 entries, 0 to 11572
# Columns: 3029 entries, SalesID to Steering_Controls_Four Wheel Standard
# dtypes: bool(3023), datetime64[ns](1), float64(1), int32(2), int64(2)
# memory usage: 33.8 MB
# None

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# Ensure all datasets have the same columns as train
valid = valid.reindex(columns=train.columns, fill_value=0)
test = test.reindex(columns=train.columns, fill_value=0)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# Separate features and target
X_train = train.drop(['SalePrice'], axis=1)
y_train = train['SalePrice']

# Split into train and validation sets


print("Missing values in y_train:", y_train.isnull().sum())
print("Missing values in X_train:", X_train.isnull().sum().sum())
# Out:
# Missing values in y_train: 0
# Missing values in X_train: 0

# %%
# Train a Random Forest model
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
X_valid = valid.drop('SalePrice', axis=1)
y_valid = valid['SalePrice']

from sklearn.metrics import mean_squared_log_error
import numpy as np

# Predict on validation set
y_pred = model.predict(X_valid)
rmsle = np.sqrt(mean_squared_log_error(y_valid, y_pred))
print('RMSLE:', rmsle)
# Out:
# RMSLE: 10.555484670601434

# %%
from sklearn.linear_model import LinearRegression

# %%
# train linear regression mode
lr_model=LinearRegression()
lr_model.fit(X_train,y_train)
# prediction
lr_model_prediction=lr_model.predict(X_valid)

# %%
from sklearn.metrics import mean_squared_error
y_pred = model.predict(X_valid)

print(f'Mean Squared Error: {mse:.2f}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       1 from sklearn.metrics import mean_squared_error
#       2 y_pred = model.predict(X_valid)
# ----> 4 print(f'Mean Squared Error: {mse:.2f}')
#
# NameError: name 'mse' is not defined

# %%
y_pred_0 = lr_model.predict(X_valid)
mse_0 = mean_squared_error(y_valid, y_pred_0)


print(f'Mean Squared Error: {mse_0:.2f}')
# Out:
# Mean Squared Error: 873604452.53

# %%
lr_pred=np.maximum(y_pred_0,0)
lr_valid=np.maximum(y_valid,0)
rmsle_0 = np.sqrt(mean_squared_log_error(lr_valid, lr_pred))
print('RMSLE_0 :', rmsle_0)
# Out:
# RMSLE_0 : 7.823407064335165

# %%
rmsle=[rmsle_0,rmsle]
model=['linear regression','random forest']
# ploting bar plot
plt.bar(model,rmsle,color=['red','blue'])
plt.xlabel('model')
plt.ylabel('Root Mean Squared Logarithmic Error')
plt.title('Compare Model Performance')
plt.show()

# %%
# Predict on the test set using the trained Random Forest model
X_test = test.drop('SalePrice', axis=1)
y_test = test['SalePrice']
y_pred_1 = lr_model.predict(X_test)
mse_0 = mean_squared_error(y_test, y_pred_1)

lr_model_prediction_1=np.maximum(y_pred_1,0)
lr_test=np.maximum(y_test,0)

rmsle_1= np.sqrt(mean_squared_log_error(lr_test, lr_model_prediction_1))
print('RMSLE_0 :', rmsle_1)
# Out:
# RMSLE_0 : 9.625694816418957

# %%
import pandas as pd

# Read the full original test file to get all SalesIDs
test_original = pd.read_csv('Test.csv')

# Create the submission DataFrame using the full SalesID column
submission_df = pd.DataFrame({
    'SalesID': test_original['SalesID'],
    'SalePrice': lr_model_prediction_1  # This should be the same length as test_original
})

# Save to CSV
submission_df.to_csv('test_predictions.csv', index=False, float_format='%.2f')

# Show the first 5 rows
submission_df.head()
submission_df.shape
# Out:
# (12457, 2)
